# %% [markdown]
# ## **Data Analysis Project - Rapido Analysis**

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### *Import raw data*

# %%
df = pd.read_csv("C:/Users/ASUS TUF/OneDrive/RAPIDO PY PROJ/rides_data.csv")

# %% [markdown]
# ##

# %%
df.head(6

)
# Out:
#       services        date     time ride_status                  source  \
# 0  cab economy  15-07-2024  30:40.5   completed         Balagere Harbor
# 1         auto  05-07-2024  36:51.5   completed  Basavanagudi 3rd Block
# 2         auto  23-07-2024  05:37.5   cancelled        Babusapalya Cove
# 3  cab economy  24-06-2024  45:10.5   completed       Mahadevapura Mews
# 4  cab economy  15-07-2024  26:44.5   completed         Ganganagar Cove
# 5         auto  02-07-2024  28:29.5   completed         HSR Layout Area
#
#                 destination  duration             ride_id  distance  \
# 0           Harohalli Nagar        39  RD3161218751875354     27.21
# 1      Bikasipura 1st Stage        89  RD8171514284594096     34.03
# 2         Kothaguda Terrace        25  RD9376481122237926     20.24
# 3            Kanakapura Arc        89  RD3676889143182765     31.17
# 4  Basaveshwaranagar Colony        95  RD6639410275948084     27.21
# ...

# %%
print("size of data:",df.shape )
# Out:
# size of data: (50000, 13)
